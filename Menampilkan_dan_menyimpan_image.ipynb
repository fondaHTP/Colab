# %%
# memanggil drive google
from google.colab import drive
drive.mount('/content/drives/')
# Out:
# Mounted at /content/drives/

# %%
# Baca File Image
import cv2
from google.colab.patches import cv2_imshow
img = cv2.imread('/content/drives/MyDrive/Colab Files/Cat.jpg', cv2.IMREAD_UNCHANGED)

# Tampilkan Gambar
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=385x427 at 0x7F4AB672A810>

# %%
# Ukuran gambar
print (img.shape)
# Out:
# (427, 385, 3)

# %%
# Tampilkan gambar beserta ukuran
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
# Ubah gambar ke grayscale
img = cv2.imread('/content/drives/MyDrive/Colab Files/Cat.jpg', cv2.IMREAD_GRAYSCALE)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=385x427 at 0x7F4AB61AD350>

# %%
# Lihat ukuran gambar
print (img.shape)
# Out:
# (427, 385)

# %%
# SImpan Gambar
cv2.imwrite('/content/drives/MyDrive/Colab Files/Catgrey.jpg',img)
# Out:
# True
